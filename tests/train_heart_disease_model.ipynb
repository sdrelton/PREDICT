# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix

# %%
data = pd.read_csv('heart_disease_df.csv')
data
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 292  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 293  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 294  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 295  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 296  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca  thal  target
# 0      3.0  0.0   6.0       0
# 1      2.0  3.0   3.0       1
# 2      2.0  2.0   7.0       1
# 3      3.0  0.0   3.0       0
# 4      1.0  0.0   3.0       0
# ..     ...  ...   ...     ...
# 292    2.0  0.0   7.0       1
# 293    2.0  0.0   7.0       1
# 294    2.0  2.0   7.0       1
# 295    2.0  1.0   7.0       1
# 296    2.0  1.0   3.0       1
#
# [297 rows x 14 columns]

# %%
print("Percentage with heart disease:",(len(data[data['target'] == 1]))/ len(data) *100, "%")
# Out:
# Percentage with heart disease: 46.12794612794613 %

# %%
feature_columns = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']

X = data[feature_columns]
y = data['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Count the number of 1's (heart disease patients)
num_ones = y_test.sum()
print(f"Percentage of people with heart disease in test set: {num_ones/len(y_test) * 100:.2f}%")

model = LogisticRegression(max_iter=5000)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

y_proba = model.predict_proba(X_test)[:, 1]
y_log_proba = model.predict_log_proba(X_test)[:, 1] # Probability of heart disease

accuracy = accuracy_score(y_test, y_pred)
print(f'\nAccuracy: {accuracy:.2f}')

cm = confusion_matrix(y_test, y_pred)
print("\nConfusion matrix: \n", cm)

AUROC = roc_auc_score(y_test, y_pred)
print(f'\nAUROC: {AUROC:.2f}')

# Save the linear predictors (coefficients) and outcomes (predictions)
coefficients = model.coef_

coefs_df = pd.DataFrame(coefficients, columns=feature_columns)

coefs_df.to_csv('hd_model_coefs.csv', index=False)

pred_outcomes_df = pd.DataFrame({'outcome': y_test, 'probability': y_proba,  'y_pred': y_pred, 'y_log_proba': y_log_proba})
pred_outcomes_df.reset_index(drop=True, inplace=True)

pred_outcomes_df.to_csv('hd_model_predictions.csv', index=False)
# Out:
# Percentage of people with heart disease in test set: 45.56%
#
# Accuracy: 0.88
#
# Confusion matrix:
#  [[45  4]
#  [ 7 34]]
#
# AUROC: 0.87

# %%
pred_outcomes_df
# Out:
#     outcome  probability  y_pred  y_log_proba
# 0         0     0.025111       0    -3.684449
# 1         1     0.237214       0    -1.438791
# 2         0     0.021371       0    -3.845726
# 3         1     0.986164       1    -0.013933
# 4         0     0.044650       0    -3.108898
# ..      ...          ...     ...          ...
# 85        0     0.103373       0    -2.269409
# 86        0     0.399297       0    -0.918049
# 87        1     0.855277       1    -0.156330
# 88        0     0.151526       0    -1.886995
# 89        1     0.976072       1    -0.024219
#
# [90 rows x 4 columns]
